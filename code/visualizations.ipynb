# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import .shp file
gdf = gpd.read_file('../data/BL_QA_editedJK.shp')

# %%
# group df by area and summarize Shape_Area by sum
gdf_grouped = gdf.groupby('area').agg({'Shape_Area': 'sum'}).reset_index()
gdf_grouped
# Out:
#           area     Shape_Area
# 0   industrial  132641.574903
# 1  residential   83487.396389
# 2        rural   82739.756797

# %%
# group gdf by area and sum up the values of shape_area

# %%
# group by QA_categor and sum the Shape_Area for each group in a bar plot

gdf.groupby('QA_categor')['Shape_Area'].sum().plot(kind='bar')
plt.savefig('../LaTex/figures/area_by_category.pdf')

# %%
gdf.plot(color=QA_categor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 gdf.plot(color=QA_categor)
#
# NameError: name 'QA_categor' is not defined

# %%
(15.68+16.31+9.2+9.5+9.8+25)*5/100+1
# Out:
# 5.2745
